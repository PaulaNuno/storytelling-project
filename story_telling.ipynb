# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image
from IPython.core.display import HTML

# %%
Image(filename="images/descarga.jpeg")

# %%
Image(filename="images/correlation.png")

# %%
Image(filename="images/Top 10 publishers.png")

# %%
Image(filename="images/top_10_games.jpg")
